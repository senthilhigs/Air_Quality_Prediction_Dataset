# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image
from sklearn.feature_extraction.text import TfidfVectorizer

# ======================
# CONFIG
# ======================
image_size = 64
batch_size = 16
noise_dim = 100
epochs = 50

image_dir = "/content/drive/MyDrive/New Dataset/Images/"
csv_path = "/content/drive/MyDrive/New Dataset/data_cls.csv"

os.makedirs("generated", exist_ok=True)

# ======================
# LOAD DATA
# ======================
data = pd.read_csv(csv_path)

images = []
for img_name in data["img_path"]:
    img_path = os.path.join(image_dir, img_name)
    print(img_path)
    img = Image.open(img_path).convert("RGB")
    img = img.resize((image_size, image_size))
    img = np.array(img) / 127.5 - 1.0
    images.append(img)

images = np.array(images, dtype=np.float32)

# ======================
# TEXT EMBEDDING
# ======================
vectorizer = TfidfVectorizer(max_features=512)
text_embeddings = vectorizer.fit_transform(data["Caption"]).toarray()
text_dim = text_embeddings.shape[1]

dataset = tf.data.Dataset.from_tensor_slices((images, text_embeddings))
dataset = dataset.shuffle(1000).batch(batch_size)

# ======================
# GENERATOR
# ======================
def build_generator():
    noise_input = layers.Input(shape=(noise_dim,))
    text_input = layers.Input(shape=(text_dim,))

    x = layers.Concatenate()([noise_input, text_input])
    x = layers.Dense(8 * 8 * 128, activation="relu")(x)
    x = layers.Reshape((8, 8, 128))(x)

    x = layers.Conv2DTranspose(128, 4, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2DTranspose(64, 4, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2DTranspose(32, 4, strides=2, padding="same", activation="relu")(x)

    output = layers.Conv2D(3, 3, padding="same", activation="tanh")(x)

    return tf.keras.Model([noise_input, text_input], output)

# ======================
# DISCRIMINATOR
# ======================
def build_discriminator():
    img_input = layers.Input(shape=(image_size, image_size, 3))
    text_input = layers.Input(shape=(text_dim,))

    x = layers.Conv2D(64, 4, strides=2, padding="same")(img_input)
    x = layers.LeakyReLU(0.2)(x)

    x = layers.Conv2D(128, 4, strides=2, padding="same")(x)
    x = layers.LeakyReLU(0.2)(x)

    x = layers.Flatten()(x)
    x = layers.Concatenate()([x, text_input])

    x = layers.Dense(1024)(x)
    x = layers.LeakyReLU(0.2)(x)

    output = layers.Dense(1, activation="sigmoid")(x)

    return tf.keras.Model([img_input, text_input], output)

# ======================
# BUILD MODELS
# ======================
generator = build_generator()
discriminator = build_discriminator()

# Compile discriminator ONCE
discriminator.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(0.0002),
    metrics=["accuracy"]
)

# Build combined GAN with frozen discriminator
discriminator.trainable = False

noise_input = layers.Input(shape=(noise_dim,))
text_input = layers.Input(shape=(text_dim,))
generated_img = generator([noise_input, text_input])
validity = discriminator([generated_img, text_input])

gan = tf.keras.Model([noise_input, text_input], validity)
gan.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(0.0002)
)

# ======================
# TRAINING LOOP
# ======================
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    for real_imgs, text_embed in dataset:

        batch_size_current = real_imgs.shape[0]

        valid = np.ones((batch_size_current, 1))
        fake = np.zeros((batch_size_current, 1))

        # Generate fake images
        noise = np.random.normal(0, 1, (batch_size_current, noise_dim))
        gen_imgs = generator.predict([noise, text_embed], verbose=0)

        # Train discriminator (REAL + FAKE)
        d_loss_real = discriminator.train_on_batch([real_imgs, text_embed], valid)
        d_loss_fake = discriminator.train_on_batch([gen_imgs, text_embed], fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train generator
        g_loss = gan.train_on_batch([noise, text_embed], valid)

    print(f"Epoch {epoch} | D Loss: {d_loss[0]:.4f} | G Loss: {g_loss:.4f}")

    # Save sample image
    sample = (gen_imgs[0] + 1) * 127.5
    sample = sample.astype(np.uint8)
    Image.fromarray(sample).save(f"generated/epoch_{epoch}.png")

generator.save("generator.h5")
discriminator.save("discriminator.h5")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2867766957.py in <cell line: 0>()
#      28 for img_name in data["img_path"]:
#      29     img_path = os.path.join(image_dir, img_name)
# ---> 30     img = Image.open(img_path).convert("RGB")
#      31     img = img.resize((image_size, image_size))
#      32     img = np.array(img) / 127.5 - 1.0
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3522         exclusive_fp = True
#    3523
# -> 3524     prefix = fp.read(16)
#    3525
#    3526     preinit()
#
# KeyboardInterrupt:
